# %% [markdown]
# <a href="https://colab.research.google.com/github/robinsantos-hue/CSCI167/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-qthxszte
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-qthxszte
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=dd519d87a7e05aad0ffef78a79897c06069032002ad9e22da659fd6b654bc019
#   Stored in directory: /tmp/pip-ephem-wheel-cache-dmymowya/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero? When number of params is same as the training example
# 2.   At what capacity do you expect the first minima of the double descent curve to appear? After the params is more than training example.
# 3. At what capacity do you expect the maximum of the double descent curve to appear? When it has enough memory.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303375, train error 89.28,  test loss 2.303912, test error 89.57
# Epoch   100, train loss 1.919443, train error 73.68,  test loss 1.755067, test error 70.00
# Epoch   200, train loss 1.906022, train error 71.45,  test loss 1.737028, test error 69.65
# Epoch   300, train loss 1.895929, train error 70.53,  test loss 1.739746, test error 69.12
# Epoch   400, train loss 1.895561, train error 72.35,  test loss 1.728866, test error 68.40
# Epoch   500, train loss 1.890379, train error 71.70,  test loss 1.729038, test error 68.88
# Epoch   600, train loss 1.891189, train error 71.15,  test loss 1.722502, test error 68.60
# Epoch   700, train loss 1.896278, train error 71.18,  test loss 1.721514, test error 69.35
# Epoch   800, train loss 1.896770, train error 70.97,  test loss 1.752309, test error 68.07
# Epoch   900, train loss 1.890149, train error 70.75,  test loss 1.735499, test error 68.30
# Training model with   4 hidden variables
# Epoch     0, train loss 2.278663, train error 88.07,  test loss 2.274204, test error 86.60
# Epoch   100, train loss 1.783469, train error 66.47,  test loss 1.634153, test error 63.20
# Epoch   200, train loss 1.766245, train error 64.32,  test loss 1.624925, test error 62.97
# Epoch   300, train loss 1.755210, train error 64.72,  test loss 1.631282, test error 63.58
# Epoch   400, train loss 1.749244, train error 64.90,  test loss 1.635381, test error 62.85
# Epoch   500, train loss 1.747603, train error 65.00,  test loss 1.634747, test error 62.95
# Epoch   600, train loss 1.746964, train error 65.30,  test loss 1.646462, test error 63.33
# Epoch   700, train loss 1.752832, train error 66.10,  test loss 1.635172, test error 63.92
# Epoch   800, train loss 1.744487, train error 65.25,  test loss 1.643590, test error 63.47
# Epoch   900, train loss 1.744824, train error 65.38,  test loss 1.638418, test error 63.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.271326, train error 85.55,  test loss 2.262033, test error 85.40
# Epoch   100, train loss 1.684889, train error 61.22,  test loss 1.507760, test error 57.97
# Epoch   200, train loss 1.643509, train error 58.58,  test loss 1.485238, test error 57.22
# Epoch   300, train loss 1.630174, train error 58.45,  test loss 1.485400, test error 57.65
# Epoch   400, train loss 1.624275, train error 57.88,  test loss 1.489971, test error 57.30
# Epoch   500, train loss 1.620016, train error 57.22,  test loss 1.493461, test error 57.45
# Epoch   600, train loss 1.616619, train error 56.88,  test loss 1.487160, test error 57.28
# Epoch   700, train loss 1.609703, train error 57.20,  test loss 1.489065, test error 57.25
# Epoch   800, train loss 1.608219, train error 57.58,  test loss 1.494478, test error 57.42
# Epoch   900, train loss 1.609330, train error 57.47,  test loss 1.501719, test error 57.78
# Training model with   8 hidden variables
# Epoch     0, train loss 2.287154, train error 86.65,  test loss 2.283967, test error 86.22
# Epoch   100, train loss 1.640007, train error 58.58,  test loss 1.471021, test error 57.12
# Epoch   200, train loss 1.586092, train error 56.83,  test loss 1.465108, test error 56.53
# Epoch   300, train loss 1.568352, train error 55.92,  test loss 1.456054, test error 55.78
# Epoch   400, train loss 1.560326, train error 55.40,  test loss 1.468616, test error 56.75
# Epoch   500, train loss 1.554587, train error 55.92,  test loss 1.484538, test error 57.50
# Epoch   600, train loss 1.539997, train error 55.78,  test loss 1.473813, test error 56.88
# Epoch   700, train loss 1.537450, train error 55.22,  test loss 1.469845, test error 56.35
# Epoch   800, train loss 1.541254, train error 55.83,  test loss 1.481012, test error 56.75
# Epoch   900, train loss 1.534100, train error 55.12,  test loss 1.488343, test error 57.25
# Training model with  10 hidden variables
# Epoch     0, train loss 2.200855, train error 81.70,  test loss 2.181123, test error 81.32
# Epoch   100, train loss 1.610927, train error 57.12,  test loss 1.453241, test error 55.40
# Epoch   200, train loss 1.536544, train error 54.30,  test loss 1.403745, test error 54.42
# Epoch   300, train loss 1.516365, train error 52.90,  test loss 1.414056, test error 54.38
# Epoch   400, train loss 1.494243, train error 51.85,  test loss 1.431073, test error 53.42
# Epoch   500, train loss 1.489824, train error 51.60,  test loss 1.453013, test error 54.30
# Epoch   600, train loss 1.473023, train error 51.38,  test loss 1.460268, test error 53.60
# Epoch   700, train loss 1.466305, train error 50.97,  test loss 1.467146, test error 53.70
# Epoch   800, train loss 1.463952, train error 51.12,  test loss 1.496915, test error 53.85
# Epoch   900, train loss 1.455833, train error 51.45,  test loss 1.488783, test error 54.20
# Training model with  14 hidden variables
# Epoch     0, train loss 2.209382, train error 82.82,  test loss 2.186716, test error 80.95
# Epoch   100, train loss 1.461529, train error 49.65,  test loss 1.368168, test error 52.83
# Epoch   200, train loss 1.376537, train error 47.55,  test loss 1.340500, test error 49.80
# Epoch   300, train loss 1.345209, train error 45.38,  test loss 1.336501, test error 49.58
# Epoch   400, train loss 1.315355, train error 44.28,  test loss 1.341669, test error 49.00
# Epoch   500, train loss 1.298266, train error 44.50,  test loss 1.347415, test error 48.80
# Epoch   600, train loss 1.293958, train error 44.22,  test loss 1.348188, test error 48.17
# Epoch   700, train loss 1.291897, train error 43.90,  test loss 1.370164, test error 48.78
# Epoch   800, train loss 1.279947, train error 43.25,  test loss 1.380324, test error 49.08
# Epoch   900, train loss 1.275973, train error 43.45,  test loss 1.385821, test error 49.15
# Training model with  18 hidden variables
# Epoch     0, train loss 2.116188, train error 79.38,  test loss 2.071891, test error 78.85
# Epoch   100, train loss 1.409363, train error 47.55,  test loss 1.362522, test error 50.42
# Epoch   200, train loss 1.271566, train error 41.78,  test loss 1.331618, test error 48.20
# Epoch   300, train loss 1.214715, train error 39.78,  test loss 1.390841, test error 49.20
# Epoch   400, train loss 1.173522, train error 38.70,  test loss 1.419994, test error 48.90
# Epoch   500, train loss 1.143458, train error 37.95,  test loss 1.464422, test error 49.65
# Epoch   600, train loss 1.133020, train error 37.22,  test loss 1.470360, test error 49.78
# Epoch   700, train loss 1.123927, train error 36.88,  test loss 1.502819, test error 49.88
# Epoch   800, train loss 1.120241, train error 37.25,  test loss 1.534471, test error 50.80
# Epoch   900, train loss 1.113908, train error 36.58,  test loss 1.527720, test error 50.53
# Training model with  22 hidden variables
# Epoch     0, train loss 2.137653, train error 78.55,  test loss 2.106246, test error 78.80
# Epoch   100, train loss 1.269690, train error 41.75,  test loss 1.305808, test error 49.30
# Epoch   200, train loss 1.149028, train error 38.62,  test loss 1.363099, test error 49.60
# Epoch   300, train loss 1.086131, train error 35.60,  test loss 1.446502, test error 50.17
# Epoch   400, train loss 1.042490, train error 35.57,  test loss 1.500550, test error 50.70
# Epoch   500, train loss 1.020723, train error 34.55,  test loss 1.565008, test error 51.88
# Epoch   600, train loss 1.011645, train error 33.78,  test loss 1.626246, test error 52.95
# Epoch   700, train loss 0.997638, train error 34.40,  test loss 1.660388, test error 52.47
# Epoch   800, train loss 0.976687, train error 33.43,  test loss 1.691092, test error 53.08
# Epoch   900, train loss 0.979933, train error 33.47,  test loss 1.740410, test error 53.17
# Training model with  26 hidden variables
# Epoch     0, train loss 2.188208, train error 79.50,  test loss 2.152119, test error 79.70
# Epoch   100, train loss 1.189218, train error 38.72,  test loss 1.291919, test error 48.08
# Epoch   200, train loss 1.049582, train error 34.72,  test loss 1.420321, test error 50.05
# Epoch   300, train loss 0.963783, train error 31.70,  test loss 1.472847, test error 49.62
# Epoch   400, train loss 0.915850, train error 30.20,  test loss 1.570249, test error 51.28
# Epoch   500, train loss 0.869178, train error 29.53,  test loss 1.687885, test error 53.05
# Epoch   600, train loss 0.840583, train error 28.05,  test loss 1.779046, test error 52.35
# Epoch   700, train loss 0.813332, train error 26.85,  test loss 1.878387, test error 53.50
# Epoch   800, train loss 0.816166, train error 27.47,  test loss 1.992425, test error 55.25
# Epoch   900, train loss 0.814241, train error 27.25,  test loss 2.048422, test error 53.92
# Training model with  30 hidden variables
# Epoch     0, train loss 2.152277, train error 79.82,  test loss 2.122944, test error 79.12
# Epoch   100, train loss 1.115162, train error 35.95,  test loss 1.328394, test error 48.62
# Epoch   200, train loss 0.925549, train error 29.88,  test loss 1.467515, test error 49.00
# Epoch   300, train loss 0.842866, train error 27.68,  test loss 1.667966, test error 51.70
# Epoch   400, train loss 0.788404, train error 26.50,  test loss 1.834473, test error 52.75
# Epoch   500, train loss 0.760603, train error 26.32,  test loss 2.005362, test error 53.05
# Epoch   600, train loss 0.696570, train error 23.85,  test loss 2.132078, test error 53.25
# Epoch   700, train loss 0.685590, train error 24.22,  test loss 2.242184, test error 53.08
# Epoch   800, train loss 0.681053, train error 24.10,  test loss 2.328321, test error 55.20
# Epoch   900, train loss 0.668494, train error 23.15,  test loss 2.455829, test error 55.17
# Training model with  35 hidden variables
# Epoch     0, train loss 2.185314, train error 79.97,  test loss 2.187865, test error 79.97
# Epoch   100, train loss 1.006317, train error 33.12,  test loss 1.377780, test error 49.03
# Epoch   200, train loss 0.783764, train error 26.05,  test loss 1.676329, test error 51.15
# Epoch   300, train loss 0.648597, train error 22.47,  test loss 2.026016, test error 53.22
# Epoch   400, train loss 0.596430, train error 20.45,  test loss 2.369213, test error 53.35
# Epoch   500, train loss 0.537286, train error 18.47,  test loss 2.711484, test error 54.53
# Epoch   600, train loss 0.502503, train error 17.22,  test loss 3.043964, test error 55.20
# Epoch   700, train loss 0.477746, train error 17.35,  test loss 3.358413, test error 55.03
# Epoch   800, train loss 0.430791, train error 14.05,  test loss 3.522163, test error 55.65
# Epoch   900, train loss 0.431194, train error 14.50,  test loss 3.770313, test error 55.45
# Training model with  40 hidden variables
# Epoch     0, train loss 2.070616, train error 77.38,  test loss 1.999017, test error 76.18
# Epoch   100, train loss 0.928391, train error 28.65,  test loss 1.413763, test error 49.03
# Epoch   200, train loss 0.651604, train error 20.88,  test loss 1.827422, test error 51.33
# Epoch   300, train loss 0.516118, train error 16.20,  test loss 2.357745, test error 54.12
# Epoch   400, train loss 0.432739, train error 14.35,  test loss 2.965097, test error 55.08
# Epoch   500, train loss 0.375437, train error 12.78,  test loss 3.645707, test error 55.25
# Epoch   600, train loss 0.358339, train error 12.53,  test loss 4.408548, test error 55.72
# Epoch   700, train loss 0.299293, train error 10.12,  test loss 5.086104, test error 56.72
# Epoch   800, train loss 0.246121, train error 8.10,  test loss 5.651484, test error 56.00
# Epoch   900, train loss 0.282310, train error 9.85,  test loss 6.296447, test error 56.47
# Training model with  45 hidden variables
# Epoch     0, train loss 2.078202, train error 78.18,  test loss 2.054159, test error 76.70
# Epoch   100, train loss 0.796209, train error 25.30,  test loss 1.565761, test error 51.17
# Epoch   200, train loss 0.477854, train error 15.10,  test loss 2.295533, test error 53.83
# Epoch   300, train loss 0.311314, train error 9.80,  test loss 3.326769, test error 53.88
# Epoch   400, train loss 0.207241, train error 6.80,  test loss 4.648958, test error 54.62
# Epoch   500, train loss 0.208067, train error 7.45,  test loss 6.050381, test error 55.53
# Epoch   600, train loss 0.269959, train error 9.85,  test loss 7.326030, test error 55.42
# Epoch   700, train loss 0.011601, train error 0.00,  test loss 8.189765, test error 56.08
# Epoch   800, train loss 0.007536, train error 0.00,  test loss 8.812204, test error 56.12
# Epoch   900, train loss 0.005711, train error 0.00,  test loss 9.287756, test error 56.17
# Training model with  50 hidden variables
# Epoch     0, train loss 2.077294, train error 77.03,  test loss 2.052846, test error 77.38
# Epoch   100, train loss 0.723503, train error 22.60,  test loss 1.625266, test error 51.12
# Epoch   200, train loss 0.325304, train error 9.25,  test loss 2.638931, test error 53.90
# Epoch   300, train loss 0.131598, train error 2.62,  test loss 4.317874, test error 55.28
# Epoch   400, train loss 0.028064, train error 0.03,  test loss 5.831662, test error 55.25
# Epoch   500, train loss 0.046639, train error 0.65,  test loss 6.634655, test error 54.88
# Epoch   600, train loss 0.007443, train error 0.00,  test loss 7.362906, test error 55.22
# Epoch   700, train loss 0.005292, train error 0.00,  test loss 7.817754, test error 55.35
# Epoch   800, train loss 0.004104, train error 0.00,  test loss 8.183450, test error 55.38
# Epoch   900, train loss 0.003324, train error 0.00,  test loss 8.479167, test error 55.38
# Training model with  55 hidden variables
# Epoch     0, train loss 2.052832, train error 76.45,  test loss 1.974818, test error 76.55
# Epoch   100, train loss 0.628006, train error 19.28,  test loss 1.684942, test error 50.97
# Epoch   200, train loss 0.197519, train error 4.38,  test loss 3.088606, test error 54.42
# Epoch   300, train loss 0.035268, train error 0.00,  test loss 4.794554, test error 56.17
# Epoch   400, train loss 0.013650, train error 0.00,  test loss 5.721899, test error 55.78
# Epoch   500, train loss 0.007929, train error 0.00,  test loss 6.307501, test error 56.12
# Epoch   600, train loss 0.005496, train error 0.00,  test loss 6.721127, test error 55.85
# Epoch   700, train loss 0.004132, train error 0.00,  test loss 7.042425, test error 56.05
# Epoch   800, train loss 0.003279, train error 0.00,  test loss 7.305458, test error 55.85
# Epoch   900, train loss 0.002700, train error 0.00,  test loss 7.533198, test error 55.72
# Training model with  60 hidden variables
# Epoch     0, train loss 2.072640, train error 76.40,  test loss 2.037251, test error 76.38
# Epoch   100, train loss 0.520218, train error 15.20,  test loss 1.760138, test error 51.12
# Epoch   200, train loss 0.092233, train error 0.60,  test loss 3.424717, test error 55.15
# Epoch   300, train loss 0.018906, train error 0.00,  test loss 4.712893, test error 55.40
# Epoch   400, train loss 0.009307, train error 0.00,  test loss 5.369013, test error 55.22
# Epoch   500, train loss 0.005873, train error 0.00,  test loss 5.808677, test error 55.20
# Epoch   600, train loss 0.004220, train error 0.00,  test loss 6.138700, test error 55.15
# Epoch   700, train loss 0.003232, train error 0.00,  test loss 6.402170, test error 55.28
# Epoch   800, train loss 0.002599, train error 0.00,  test loss 6.618031, test error 55.22
# Epoch   900, train loss 0.002160, train error 0.00,  test loss 6.806703, test error 55.25
# Training model with  70 hidden variables
# Epoch     0, train loss 2.054548, train error 76.15,  test loss 2.013414, test error 75.85
# Epoch   100, train loss 0.380112, train error 9.03,  test loss 1.981635, test error 52.60
# Epoch   200, train loss 0.036917, train error 0.03,  test loss 3.650756, test error 54.28
# Epoch   300, train loss 0.011484, train error 0.00,  test loss 4.481510, test error 54.47
# Epoch   400, train loss 0.006237, train error 0.00,  test loss 4.929901, test error 54.15
# Epoch   500, train loss 0.004147, train error 0.00,  test loss 5.244476, test error 54.40
# Epoch   600, train loss 0.003053, train error 0.00,  test loss 5.476857, test error 54.38
# Epoch   700, train loss 0.002393, train error 0.00,  test loss 5.666563, test error 54.28
# Epoch   800, train loss 0.001950, train error 0.00,  test loss 5.822945, test error 54.42
# Epoch   900, train loss 0.001637, train error 0.00,  test loss 5.959332, test error 54.42
# Training model with  80 hidden variables
# Epoch     0, train loss 2.039526, train error 75.53,  test loss 1.982276, test error 74.97
# Epoch   100, train loss 0.210040, train error 3.28,  test loss 2.113783, test error 51.80
# Epoch   200, train loss 0.019713, train error 0.00,  test loss 3.427320, test error 52.92
# Epoch   300, train loss 0.007978, train error 0.00,  test loss 3.977117, test error 52.78
# Epoch   400, train loss 0.004756, train error 0.00,  test loss 4.307297, test error 52.85
# Epoch   500, train loss 0.003292, train error 0.00,  test loss 4.540831, test error 52.88
# Epoch   600, train loss 0.002487, train error 0.00,  test loss 4.719444, test error 52.85
# Epoch   700, train loss 0.001975, train error 0.00,  test loss 4.868019, test error 52.78
# Epoch   800, train loss 0.001630, train error 0.00,  test loss 4.994186, test error 52.70
# Epoch   900, train loss 0.001378, train error 0.00,  test loss 5.102562, test error 52.85
# Training model with  90 hidden variables
# Epoch     0, train loss 2.005772, train error 74.90,  test loss 1.944966, test error 74.88
# Epoch   100, train loss 0.136296, train error 1.12,  test loss 2.223648, test error 51.62
# Epoch   200, train loss 0.014271, train error 0.00,  test loss 3.204949, test error 51.83
# Epoch   300, train loss 0.006413, train error 0.00,  test loss 3.606588, test error 51.65
# Epoch   400, train loss 0.003931, train error 0.00,  test loss 3.856601, test error 51.85
# Epoch   500, train loss 0.002780, train error 0.00,  test loss 4.036802, test error 51.65
# Epoch   600, train loss 0.002120, train error 0.00,  test loss 4.179671, test error 51.62
# Epoch   700, train loss 0.001697, train error 0.00,  test loss 4.297204, test error 51.62
# Epoch   800, train loss 0.001406, train error 0.00,  test loss 4.394800, test error 51.75
# Epoch   900, train loss 0.001194, train error 0.00,  test loss 4.480182, test error 51.80
# Training model with 100 hidden variables
# Epoch     0, train loss 2.015671, train error 74.15,  test loss 1.972270, test error 74.45
# Epoch   100, train loss 0.097448, train error 0.15,  test loss 2.203279, test error 50.47
# Epoch   200, train loss 0.012215, train error 0.00,  test loss 3.027459, test error 50.58
# Epoch   300, train loss 0.005665, train error 0.00,  test loss 3.383404, test error 50.58
# Epoch   400, train loss 0.003525, train error 0.00,  test loss 3.606537, test error 50.50
# Epoch   500, train loss 0.002513, train error 0.00,  test loss 3.767821, test error 50.58
# Epoch   600, train loss 0.001918, train error 0.00,  test loss 3.897851, test error 50.70
# Epoch   700, train loss 0.001543, train error 0.00,  test loss 4.004548, test error 50.72
# Epoch   800, train loss 0.001281, train error 0.00,  test loss 4.094276, test error 50.78
# Epoch   900, train loss 0.001091, train error 0.00,  test loss 4.172393, test error 50.83
# Training model with 120 hidden variables
# Epoch     0, train loss 1.978223, train error 72.70,  test loss 1.907754, test error 73.38
# Epoch   100, train loss 0.050929, train error 0.00,  test loss 2.234490, test error 50.05
# Epoch   200, train loss 0.009546, train error 0.00,  test loss 2.846666, test error 50.65
# Epoch   300, train loss 0.004717, train error 0.00,  test loss 3.126952, test error 50.53
# Epoch   400, train loss 0.003015, train error 0.00,  test loss 3.306911, test error 50.50
# Epoch   500, train loss 0.002171, train error 0.00,  test loss 3.441676, test error 50.35
# Epoch   600, train loss 0.001677, train error 0.00,  test loss 3.546926, test error 50.47
# Epoch   700, train loss 0.001356, train error 0.00,  test loss 3.634741, test error 50.65
# Epoch   800, train loss 0.001131, train error 0.00,  test loss 3.709382, test error 50.50
# Epoch   900, train loss 0.000966, train error 0.00,  test loss 3.774188, test error 50.55
# Training model with 140 hidden variables
# Epoch     0, train loss 1.937906, train error 71.68,  test loss 1.890082, test error 74.20
# Epoch   100, train loss 0.035489, train error 0.00,  test loss 2.131987, test error 49.15
# Epoch   200, train loss 0.008034, train error 0.00,  test loss 2.616406, test error 49.12
# Epoch   300, train loss 0.004124, train error 0.00,  test loss 2.847887, test error 49.12
# Epoch   400, train loss 0.002678, train error 0.00,  test loss 2.999639, test error 49.08
# Epoch   500, train loss 0.001949, train error 0.00,  test loss 3.111396, test error 49.12
# Epoch   600, train loss 0.001514, train error 0.00,  test loss 3.200761, test error 49.12
# Epoch   700, train loss 0.001229, train error 0.00,  test loss 3.275496, test error 49.10
# Epoch   800, train loss 0.001029, train error 0.00,  test loss 3.338897, test error 49.15
# Epoch   900, train loss 0.000881, train error 0.00,  test loss 3.394172, test error 49.15
# Training model with 160 hidden variables
# Epoch     0, train loss 1.930925, train error 70.40,  test loss 1.860847, test error 73.05
# Epoch   100, train loss 0.028605, train error 0.00,  test loss 2.153714, test error 48.78
# Epoch   200, train loss 0.007048, train error 0.00,  test loss 2.542183, test error 48.78
# Epoch   300, train loss 0.003717, train error 0.00,  test loss 2.743872, test error 48.65
# Epoch   400, train loss 0.002447, train error 0.00,  test loss 2.875697, test error 48.58
# Epoch   500, train loss 0.001794, train error 0.00,  test loss 2.977292, test error 48.50
# Epoch   600, train loss 0.001402, train error 0.00,  test loss 3.056384, test error 48.42
# Epoch   700, train loss 0.001143, train error 0.00,  test loss 3.122643, test error 48.45
# Epoch   800, train loss 0.000960, train error 0.00,  test loss 3.179886, test error 48.40
# Epoch   900, train loss 0.000824, train error 0.00,  test loss 3.229679, test error 48.40
# Training model with 180 hidden variables
# Epoch     0, train loss 1.912965, train error 70.25,  test loss 1.850005, test error 71.12
# Epoch   100, train loss 0.025361, train error 0.00,  test loss 2.106828, test error 49.35
# Epoch   200, train loss 0.006663, train error 0.00,  test loss 2.481225, test error 49.30
# Epoch   300, train loss 0.003541, train error 0.00,  test loss 2.666280, test error 49.30
# Epoch   400, train loss 0.002341, train error 0.00,  test loss 2.791112, test error 49.25
# Epoch   500, train loss 0.001719, train error 0.00,  test loss 2.883681, test error 49.25
# Epoch   600, train loss 0.001345, train error 0.00,  test loss 2.958158, test error 49.33
# Epoch   700, train loss 0.001097, train error 0.00,  test loss 3.021162, test error 49.30
# Epoch   800, train loss 0.000922, train error 0.00,  test loss 3.073633, test error 49.28
# Epoch   900, train loss 0.000792, train error 0.00,  test loss 3.119803, test error 49.30
# Training model with 200 hidden variables
# Epoch     0, train loss 1.913156, train error 69.68,  test loss 1.855786, test error 71.53
# Epoch   100, train loss 0.020832, train error 0.00,  test loss 2.014271, test error 48.40
# Epoch   200, train loss 0.006022, train error 0.00,  test loss 2.328534, test error 48.22
# Epoch   300, train loss 0.003292, train error 0.00,  test loss 2.490073, test error 48.22
# Epoch   400, train loss 0.002199, train error 0.00,  test loss 2.600195, test error 48.30
# Epoch   500, train loss 0.001627, train error 0.00,  test loss 2.682458, test error 48.30
# Epoch   600, train loss 0.001279, train error 0.00,  test loss 2.749121, test error 48.28
# Epoch   700, train loss 0.001046, train error 0.00,  test loss 2.804079, test error 48.30
# Epoch   800, train loss 0.000881, train error 0.00,  test loss 2.852016, test error 48.30
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.892842, test error 48.38
# Training model with 250 hidden variables
# Epoch     0, train loss 1.910179, train error 70.38,  test loss 1.832045, test error 72.80
# Epoch   100, train loss 0.016846, train error 0.00,  test loss 1.913388, test error 46.28
# Epoch   200, train loss 0.005305, train error 0.00,  test loss 2.161153, test error 46.17
# Epoch   300, train loss 0.002960, train error 0.00,  test loss 2.296027, test error 46.10
# Epoch   400, train loss 0.002000, train error 0.00,  test loss 2.384706, test error 46.00
# Epoch   500, train loss 0.001489, train error 0.00,  test loss 2.452878, test error 46.03
# Epoch   600, train loss 0.001175, train error 0.00,  test loss 2.507321, test error 45.90
# Epoch   700, train loss 0.000965, train error 0.00,  test loss 2.553348, test error 45.90
# Epoch   800, train loss 0.000815, train error 0.00,  test loss 2.593143, test error 45.97
# Epoch   900, train loss 0.000703, train error 0.00,  test loss 2.627430, test error 46.00
# Training model with 300 hidden variables
# Epoch     0, train loss 1.883827, train error 69.18,  test loss 1.817974, test error 71.30
# Epoch   100, train loss 0.014713, train error 0.00,  test loss 1.859022, test error 46.58
# Epoch   200, train loss 0.004896, train error 0.00,  test loss 2.084009, test error 46.50
# Epoch   300, train loss 0.002769, train error 0.00,  test loss 2.202893, test error 46.20
# Epoch   400, train loss 0.001884, train error 0.00,  test loss 2.285696, test error 46.10
# Epoch   500, train loss 0.001409, train error 0.00,  test loss 2.348229, test error 46.10
# Epoch   600, train loss 0.001116, train error 0.00,  test loss 2.399142, test error 46.00
# Epoch   700, train loss 0.000918, train error 0.00,  test loss 2.441815, test error 45.95
# Epoch   800, train loss 0.000777, train error 0.00,  test loss 2.478949, test error 45.90
# Epoch   900, train loss 0.000672, train error 0.00,  test loss 2.510801, test error 45.95
# Training model with 400 hidden variables
# Epoch     0, train loss 1.848820, train error 66.25,  test loss 1.776224, test error 68.38
# Epoch   100, train loss 0.011632, train error 0.00,  test loss 1.788563, test error 47.60
# Epoch   200, train loss 0.004143, train error 0.00,  test loss 1.963466, test error 47.40
# Epoch   300, train loss 0.002402, train error 0.00,  test loss 2.063301, test error 47.30
# Epoch   400, train loss 0.001656, train error 0.00,  test loss 2.132931, test error 47.10
# Epoch   500, train loss 0.001249, train error 0.00,  test loss 2.185771, test error 47.08
# Epoch   600, train loss 0.000995, train error 0.00,  test loss 2.228531, test error 47.15
# Epoch   700, train loss 0.000822, train error 0.00,  test loss 2.265095, test error 47.10
# Epoch   800, train loss 0.000698, train error 0.00,  test loss 2.295967, test error 47.05
# Epoch   900, train loss 0.000605, train error 0.00,  test loss 2.324024, test error 47.12

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
